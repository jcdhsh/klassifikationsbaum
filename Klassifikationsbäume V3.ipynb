# %%
import seaborn

# %%
from sklearn.datasets import make_blobs

# %%
x, y = make_blobs(n_samples=1000, n_features=5, centers=4, cluster_std=3, random_state=0)

# %%
x
# Out:
# array([[  4.2900055 ,   1.2593096 ,   0.24827196,   3.66188885,
#          -0.14446058],
#        [  1.681067  ,  -2.45863333,   2.34537436,   7.18574985,
#          -1.59087155],
#        [  4.59321328,  -0.93449785,   5.19647879,  11.32842795,
#         -16.72811976],
#        ...,
#        [ -7.93096819, -14.08186468,   5.21229594,  11.04946131,
#           5.03603886],
#        [  3.09353384,   6.03137763,   0.35870238,  11.23490864,
#         -11.08959196],
#        [-10.66713243, -12.36153503,  11.97456592,   5.64940373,
#           9.05913451]])

# %%
y
# Out:
# array([0, 1, 2, 0, 0, 3, 2, 0, 3, 2, 3, 3, 1, 1, 3, 0, 1, 2, 1, 2, 0, 0,
#        2, 1, 3, 0, 3, 3, 3, 1, 2, 3, 0, 1, 3, 2, 3, 2, 2, 3, 3, 3, 3, 2,
#        1, 3, 1, 3, 1, 2, 1, 2, 0, 2, 2, 2, 0, 3, 0, 3, 2, 3, 3, 1, 2, 1,
#        0, 1, 2, 2, 3, 2, 0, 2, 0, 3, 3, 1, 2, 0, 2, 0, 3, 0, 1, 0, 1, 1,
#        2, 3, 0, 3, 1, 0, 1, 0, 1, 2, 0, 3, 2, 1, 2, 3, 2, 3, 1, 1, 2, 2,
#        3, 1, 2, 2, 2, 1, 2, 3, 1, 3, 2, 1, 3, 0, 2, 3, 0, 0, 0, 0, 0, 0,
#        3, 3, 3, 3, 1, 3, 1, 3, 3, 1, 2, 1, 0, 3, 1, 0, 3, 0, 3, 2, 0, 2,
#        2, 0, 2, 3, 0, 3, 1, 2, 1, 3, 2, 2, 2, 0, 3, 0, 2, 2, 3, 1, 1, 3,
#        1, 3, 1, 3, 2, 0, 2, 0, 2, 2, 2, 1, 1, 1, 3, 0, 1, 1, 1, 3, 3, 2,
#        2, 1, 1, 3, 3, 1, 1, 1, 2, 3, 0, 3, 0, 1, 3, 0, 3, 2, 0, 2, 1, 2,
#        0, 0, 0, 1, 0, 1, 0, 3, 1, 0, 3, 3, 2, 1, 2, 2, 2, 0, 3, 2, 1, 2,
#        1, 1, 0, 1, 3, 1, 2, 0, 2, 2, 3, 0, 3, 2, 2, 3, 0, 1, 2, 1, 2, 2,
#        3, 1, 1, 3, 1, 3, 3, 1, 3, 0, 1, 1, 2, 1, 1, 3, 3, 0, 0, 1, 1, 3,
# ...

# %%
import pandas as pd

# %%
df = pd.DataFrame(x)

# %%
seaborn.pairplot(df,hue=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-4d571bce1e2c> in <module>
# ----> 1 seaborn.pairplot(df,hue=y)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1923     # Set up the PairGrid
#    1924     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1925     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1926                     hue_order=hue_order, palette=palette, corner=corner,
# ...

# %%
seaborn.pairplot(df,hue=4)
# Out:
# C:\Users\lschmueser\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lschmueser\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lschmueser\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lschmueser\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\lschmueser\Anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
df = pd.DataFrame(x,y)

# %%
seaborn.pairplot(df)

# %%
seaborn.pairplot(df, hue=classes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-b1e9e3da9d2f> in <module>
# ----> 1 seaborn.pairplot(df, hue=classes)
#
# NameError: name 'classes' is not defined

# %%
df
# Out:
#             0          1          2          3          4
# 0    4.290005   1.259310   0.248272   3.661889  -0.144461
# 1    1.681067  -2.458633   2.345374   7.185750  -1.590872
# 2    4.593213  -0.934498   5.196479  11.328428 -16.728120
# 0   -0.061675   2.912999   3.499712  -3.724727  -1.337118
# 0    2.348517   1.409951  -0.292620   0.566496  -4.690789
# ..        ...        ...        ...        ...        ...
# 1   -0.273205  -2.541545   9.553714  11.305926   1.590382
# 1    0.605529  -2.690792   9.946217  12.060691  -1.217652
# 3   -7.930968 -14.081865   5.212296  11.049461   5.036039
# 2    3.093534   6.031378   0.358702  11.234909 -11.089592
# 3  -10.667132 -12.361535  11.974566   5.649404   9.059135
#
# [1000 rows x 5 columns]

# %%
df = pd.DataFrame(x)

# %%
df
# Out:
#              0          1          2          3          4
# 0     4.290005   1.259310   0.248272   3.661889  -0.144461
# 1     1.681067  -2.458633   2.345374   7.185750  -1.590872
# 2     4.593213  -0.934498   5.196479  11.328428 -16.728120
# 3    -0.061675   2.912999   3.499712  -3.724727  -1.337118
# 4     2.348517   1.409951  -0.292620   0.566496  -4.690789
# ..         ...        ...        ...        ...        ...
# 995  -0.273205  -2.541545   9.553714  11.305926   1.590382
# 996   0.605529  -2.690792   9.946217  12.060691  -1.217652
# 997  -7.930968 -14.081865   5.212296  11.049461   5.036039
# 998   3.093534   6.031378   0.358702  11.234909 -11.089592
# 999 -10.667132 -12.361535  11.974566   5.649404   9.059135
#
# [1000 rows x 5 columns]

# %%
df.insert(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-20c8c5ed46c6> in <module>
# ----> 1 df.insert(y)
#
# TypeError: insert() missing 2 required positional arguments: 'column' and 'value'

# %%
df.ins, 2ert(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-6973edb70f77> in <module>
# ----> 1 df.insert(5, 2)
#
# TypeError: insert() missing 1 required positional argument: 'value'

# %%
seabron.pairplot(df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-24-c926a45af4e5> in <module>
# ----> 1 seabron.pairplot(df)
#
# NameError: name 'seabron' is not defined

# %%
seaborn.pairplot(df)

# %%
seaborn.pairplot(df, hue=y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-3199dd1051ec> in <module>
# ----> 1 seaborn.pairplot(df, hue=y)
#
# ~\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\Anaconda3\lib\site-packages\seaborn\axisgrid.py in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    1923     # Set up the PairGrid
#    1924     grid_kws.setdefault("diag_sharey", diag_kind == "hist")
# -> 1925     grid = PairGrid(data, vars=vars, x_vars=x_vars, y_vars=y_vars, hue=hue,
#    1926                     hue_order=hue_order, palette=palette, corner=corner,
# ...

# %%
df.insert(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-66495ae423e0> in <module>
# ----> 1 df.insert(5)
#
# TypeError: insert() missing 2 required positional arguments: 'column' and 'value'

# %%
df.insert(5, "Zielklassen",y)

# %%
df
# Out:
#              0          1          2          3          4  Zielklassen
# 0     4.290005   1.259310   0.248272   3.661889  -0.144461            0
# 1     1.681067  -2.458633   2.345374   7.185750  -1.590872            1
# 2     4.593213  -0.934498   5.196479  11.328428 -16.728120            2
# 3    -0.061675   2.912999   3.499712  -3.724727  -1.337118            0
# 4     2.348517   1.409951  -0.292620   0.566496  -4.690789            0
# ..         ...        ...        ...        ...        ...          ...
# 995  -0.273205  -2.541545   9.553714  11.305926   1.590382            1
# 996   0.605529  -2.690792   9.946217  12.060691  -1.217652            1
# 997  -7.930968 -14.081865   5.212296  11.049461   5.036039            3
# 998   3.093534   6.031378   0.358702  11.234909 -11.089592            2
# 999 -10.667132 -12.361535  11.974566   5.649404   9.059135            3
#
# [1000 rows x 6 columns]

# %%
seaborn.pairplot(df, hue="Zielklassen")

# %%
df.rename(columns={"0": "Merkmal 1", "1": "Merkmal 2", "2": "Merkmal 3", "3": "Merkmal 4", "4": "Merkmal 5", "Zielklassen": "Bonitätsklassen"})
# Out:
#              0          1          2          3          4  Bonitätsklassen
# 0     4.290005   1.259310   0.248272   3.661889  -0.144461                0
# 1     1.681067  -2.458633   2.345374   7.185750  -1.590872                1
# 2     4.593213  -0.934498   5.196479  11.328428 -16.728120                2
# 3    -0.061675   2.912999   3.499712  -3.724727  -1.337118                0
# 4     2.348517   1.409951  -0.292620   0.566496  -4.690789                0
# ..         ...        ...        ...        ...        ...              ...
# 995  -0.273205  -2.541545   9.553714  11.305926   1.590382                1
# 996   0.605529  -2.690792   9.946217  12.060691  -1.217652                1
# 997  -7.930968 -14.081865   5.212296  11.049461   5.036039                3
# 998   3.093534   6.031378   0.358702  11.234909 -11.089592                2
# 999 -10.667132 -12.361535  11.974566   5.649404   9.059135                3
#
# [1000 rows x 6 columns]

# %%
df.rename(columns={"0": "Merkmal1"})
# Out:
#              0          1          2          3          4  Zielklassen
# 0     4.290005   1.259310   0.248272   3.661889  -0.144461            0
# 1     1.681067  -2.458633   2.345374   7.185750  -1.590872            1
# 2     4.593213  -0.934498   5.196479  11.328428 -16.728120            2
# 3    -0.061675   2.912999   3.499712  -3.724727  -1.337118            0
# 4     2.348517   1.409951  -0.292620   0.566496  -4.690789            0
# ..         ...        ...        ...        ...        ...          ...
# 995  -0.273205  -2.541545   9.553714  11.305926   1.590382            1
# 996   0.605529  -2.690792   9.946217  12.060691  -1.217652            1
# 997  -7.930968 -14.081865   5.212296  11.049461   5.036039            3
# 998   3.093534   6.031378   0.358702  11.234909 -11.089592            2
# 999 -10.667132 -12.361535  11.974566   5.649404   9.059135            3
#
# [1000 rows x 6 columns]

# %%
from sklearn import datasets, linear_model
from sklearn.model_selection import train_test_split

# %%
diabetes = datasets.load_diabetes()
X = diabetes.data
y = diabetes.target

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)
